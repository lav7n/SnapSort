# %%
from ultralytics import YOLO
import cv2
import os
import numpy as np

def detect_faces_in_folder(folder_path, confidence_threshold=0.25):
   """Detect faces in all images in a folder."""
   model = YOLO("model.pt")
   image_results = {}

   # Supported image extensions
   valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.gif')

   for filename in os.listdir(folder_path):
       if filename.lower().endswith(valid_extensions):
           image_path = os.path.join(folder_path, filename)
           image = cv2.imread(image_path)

           if image is None:
               print(f"Failed to read image: {filename}")
               continue

           results = model.predict(source=image, conf=confidence_threshold)
           face_boxes = []

           for box in results[0].boxes.xyxy:
               x1, y1, x2, y2 = map(int, box)
               face_boxes.append((x1, y1, x2, y2))
               cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

           image_results[filename] = face_boxes

   return image_results

folder_path = "/Users/lava/Documents/Code/SnapSort/ML/media"
results = detect_faces_in_folder(folder_path)

# for image_name, faces in results.items():
#     print(f"{image_name}: {len(faces)} faces detected")
#     for i, bbox in enumerate(faces, 1):
#         print(f"  Face {i}: {bbox}")
results
# Out:
# 0: 320x256 1 face, 35.5ms
# Speed: 6.7ms preprocess, 35.5ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 20.7ms
# Speed: 1.5ms preprocess, 20.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 14.1ms
# Speed: 0.7ms preprocess, 14.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 21.5ms
# Speed: 0.8ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 13.6ms
# Speed: 0.7ms preprocess, 13.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 15.1ms
# Speed: 0.6ms preprocess, 15.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x192 1 face, 11.2ms
# Speed: 0.6ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x256 1 face, 23.1ms
# Speed: 2.4ms preprocess, 23.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x256 1 face, 17.6ms
# Speed: 1.2ms preprocess, 17.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x192 1 face, 10.0ms
# Speed: 0.6ms preprocess, 10.0ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x256 1 face, 14.4ms
# Speed: 0.9ms preprocess, 14.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x192 1 face, 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x320 1 face, 15.6ms
# Speed: 0.6ms preprocess, 15.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x224 1 face, 13.4ms
# Speed: 0.9ms preprocess, 13.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 224x320 1 face, 13.9ms
# Speed: 0.6ms preprocess, 13.9ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x224 1 face, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 224)
# {'Laven2.jpg': [(345, 351, 527, 575)],
#  'laven1.jpg': [(148, 204, 248, 328)],
#  'guestarg2.jpg': [(789, 1554, 1488, 2569)],
#  'guestar2.jpg': [(933, 1344, 1562, 2245)],
#  'guestar3.jpg': [(932, 1662, 1566, 2566)],
#  'guestarg1.jpg': [(605, 1478, 1121, 2228)],
#  'guestar1.jpg': [(123, 127, 276, 331)],
#  'guestl3.jpg': [(341, 443, 836, 1047)],
#  'guest2.jpg': [(1553, 1452, 2820, 3263)],
#  'guest3.jpg': [(1079, 1453, 2353, 3449)],
#  'guestl2.jpg': [(198, 478, 630, 1131)],
#  'guest1.jpg': [(547, 1418, 1874, 3196)],
#  'guestl1.jpg': [(236, 509, 641, 1085)],
#  'aravind1.jpg': [(182, 192, 416, 543)],
#  'anish1.jpg': [(605, 433, 728, 596)],
#  'anish2.jpg': [(1167, 204, 1521, 667)],
#  'anish3.jpg': [(773, 1275, 1818, 2729)]}

# %%
from deepface import DeepFace

def GetEmbeds(folder):
    embeds = {}
    for img in os.listdir(folder):
        path = os.path.join(folder, img)
        try:
            rep = DeepFace.represent(path)
            embeds[img] = rep if rep else None
        except Exception as e:
            print(f"Error processing {img}: {e}")
    return embeds


folder = "/Users/lava/Documents/Code/SnapSort/ML/media"
embeddings = GetEmbeds(folder)
embeddings
# Out:
# Error processing Laven2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing laven1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestarg2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestar2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestar3.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestarg1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestar1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestl3.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guest2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guest3.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestl2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guest1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing guestl1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing aravind1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing anish1.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing anish2.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error processing anish3.jpg: module 'deepface.modules.modeling' has no attribute 'build_model'
# {}
